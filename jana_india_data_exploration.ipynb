# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from markdown_predictions.parse_data import LoadSalesData

# %%
load_data_sales = LoadSalesData.load_in_files("raw_data")

# %%
df = load_data_sales.sales_data

# %% [markdown]
# ### Dropping all lines without a product reference

# %%
df = df[df.reference_PRE.notnull()]

# %%
df.tail(1)
# Out:
#                 delivery_PRE window_display_PRE target_PRE gender_PRE  \
# 12929  17 SELECTIF VET HIVER      JOUR FEMME P0   3-ADULTE         FE
#
#       product_category_PRE                      family_PRE  \
# 12929                 JOUR  FA MAILLOTS DE BAIN        VET
#
#                     sub_family_PRE macro_category_PRE reference_name_PRE  \
# 12929  MAILLOTS DE BAIN FILLE  VET        Adulte Jour               LUDO
#
#       reference_PRE  ... cum_quantity_sold_POST num_sizes_POST  \
# 12929     2638017.0  ...                      1              2
#
#       num_stores_POST first_week_sale_POST rate_of_sale_POST  \
# 12929               2             2018-S16              0.02
#
#        cum_sellthrough_POST warehouse_stock_POST zero_stock_POST  \
# 12929                 100 %                    0               0
#
#       avail_warehouse_stock_POST %_POST
# 12929                          0     0%
#
# [1 rows x 74 columns]

# %%
df.columns[df.dtypes==object]
# Out:
# Index(['delivery_PRE', 'window_display_PRE', 'target_PRE', 'gender_PRE',
#        'product_category_PRE', 'family_PRE', 'sub_family_PRE',
#        'macro_category_PRE', 'reference_name_PRE', 'reference_PRE',
#        'description_PRE', 'color_PRE', 'material_PRE', 'seasonality_PRE',
#        'price_PRE', 'turnover_PRE', 'sub_target_PRE', 'turnover_w_sub1_PRE',
#        'turnover_w_sub2_PRE', 'turnover_w_sub3_PRE', 'quantity_sold_PRE',
#        'quantity_sold_sub1_PRE', 'quantity_sold_sub2_PRE',
#        'quantity_sold_sub3_PRE', 'discount_rate_PRE', 'discount_rate_sub1_PRE',
#        'store_stock_PRE', 'stock_transit_PRE', 'total_store_stock_PRE',
#        'weekly_cover_PRE', 'cum_turnover_PRE', 'cum_discount_rate_PRE',
#        'cum_quantity_sold_PRE', 'num_sizes_PRE', 'num_stores_PRE',
#        'first_week_sale_PRE', 'rate_of_sale_PRE', 'cum_sellthrough_PRE',
#        'warehouse_stock_PRE', 'zero_stock_PRE', 'avail_warehouse_stock_PRE',
#        '%_PRE', 'season_PRE', 'reference_POST', 'seasonality_POST',
#        'price_POST', 'turnover_POST', 'turnover_w_sub1_POST',
#        'turnover_w_sub2_POST', 'turnover_w_sub3_POST', 'quantity_sold_POST',
#        'quantity_sold_sub1_POST', 'quantity_sold_sub2_POST',
#        'quantity_sold_sub3_POST', 'discount_rate_POST',
#        'discount_rate_sub1_POST', 'store_stock_POST', 'stock_transit_POST',
#        'total_store_stock_POST', 'weekly_cover_POST', 'cum_turnover_POST',
#        'cum_discount_rate_POST', 'cum_quantity_sold_POST',
#        'first_week_sale_POST', 'rate_of_sale_POST', 'cum_sellthrough_POST',
#        'warehouse_stock_POST', 'avail_warehouse_stock_POST', '%_POST'],
#       dtype='object')

# %%
df.turnover_w_sub1_PRE
# Out:
# 0             0  €
# 1        16,998  €
# 2        15,372  €
# 3        15,834  €
# 4        13,387  €
#            ...
# 12925       287  €
# 12926         0  €
# 12927     1,215  €
# 12928       253  €
# 12929         0  €
# Name: turnover_w_sub1_PRE, Length: 12924, dtype: object

# %%
df.isnull().sum()
# Out:
# delivery_PRE                  0
# window_display_PRE            0
# target_PRE                    0
# gender_PRE                    0
# product_category_PRE          0
#                              ..
# cum_sellthrough_POST          0
# warehouse_stock_POST          0
# zero_stock_POST               0
# avail_warehouse_stock_POST    0
# %_POST                        0
# Length: 74, dtype: int64

# %% [markdown]
# ### Getting rid of euro sing and space

# %%
euro_col = [col for col, data in df.items() if "€" in str(data[0])]

# %%
df[euro_col] = df[euro_col].replace({r' +\€':''}, regex = True)
# Out:
# /Users/jana/.pyenv/versions/markdown_predictions/lib/python3.8/site-packages/pandas/core/frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %% [markdown]
# ### Getting rid of commas in the DataFrame

# %%
df[euro_col] = df[euro_col].replace(',','', regex=True)

# %% [markdown]
# ### Getting rid of %

# %%
pct_col = [col for col, data in df.items() if "%" in str(data[0])]

# %%
pct_col
# Out:
# ['discount_rate_PRE',
#  'discount_rate_sub1_PRE',
#  'cum_discount_rate_PRE',
#  'cum_sellthrough_PRE',
#  '%_PRE',
#  'cum_discount_rate_POST',
#  'cum_sellthrough_POST',
#  '%_POST']

# %%
df[pct_col] = df[pct_col].replace({r'([ +]?)%':''}, regex = True)

# %%
df[df.discount_rate_PRE == '-']
# Out:
#                        delivery_PRE              window_display_PRE  \
# 1810   AH2018 SELECTIF EARLY SEASON  18 S VET EARLY JRBB-RDC GRAPHI
# 1811     PERM SELECTIF EARLY SEASON       PERM S SVET EARLY PERM SV
# 1812            17 SELECTIF VET ETE                         BB F P4
# 1813            17 SELECTIF SVT ETE          G PT LIGNE ICONIQUE P1
# 1814     PERM SELECTIF EARLY SEASON       PERM S SVET EARLY PERM SV
# ...                             ...                             ...
# 12909           17 SELECTIF VET ETE                         BB G P1
# 12910           17 SELECTIF SVT ETE          SOUS VETEMENT FEMME P0
# 12911           17 SELECTIF VET ETE               NUIT PTE FILLE P2
# 12912         17 SELECTIF VET HIVER                         BB G P0
# 12917           13 SELECTIF VET ETE                   JOUR FEMME P1
#
#       target_PRE gender_PRE product_category_PRE  \
# 1810      1-BEBE         MI                 AISV
# 1811    2-ENFANT         FE               SS VET
# 1812      1-BEBE         FE                 JOUR
# 1813    2-ENFANT         MA               SS VET
# 1814      1-BEBE         MI               SS VET
# ...          ...        ...                  ...
# 12909     1-BEBE         MA                 JOUR
# 12910   3-ADULTE         FE               SS VET
# 12911   2-ENFANT         FE                 NUIT
# 12912     1-BEBE         MA                 JOUR
# 12917   3-ADULTE         FE                 JOUR
#
#                            family_PRE               sub_family_PRE  \
# 1810   FA TEE SHIRTS              S/V  TEE SHIRTS ML           S/V
# 1811   FA CULOTTES                S/V  CULOTTES                S/V
# 1812   FA MAILLOTS DE BAIN        VET  MAILLOTS DE BAIN FILLE  VET
# 1813   FA DEBARDEURS              S/V  DEBARDEURS              S/V
# 1814                     FA BODIES SM                 SF BODIES SM
# ...                               ...                          ...
# 12909  FA SALOPETTES              VET  SALOPETTES COURTES      VET
# 12910  FA PANTALON                S/V  PANTALON                S/V
# 12911  FA PYJAMAS                 VET  PYJACOURTS FILLE        VET
# 12912  FA PANTALONS JOUR          VET  PANTALONS JOUR          VET
# 12917  FA GROSSES PIECES          VET  CIRES, COUPE VENT       VET
#
#       macro_category_PRE reference_name_PRE reference_PRE  ...  \
# 1810         Bébé Debout         LOT 2 TSML     4646991.0  ...
# 1811     Enfant Sous-Vêt         3 CULOTTES     4901000.0  ...
# 1812         Bébé Debout             FLAVIO     2204760.0  ...
# 1813     Enfant Sous-Vêt                  -     2373400.0  ...
# 1814       Bébé Sous-Vêt         LOT X3 BOD     4879800.0  ...
# ...                  ...                ...           ...  ...
# 12909        Bébé Debout             FRACAS     2281282.0  ...
# 12910    Adulte Sous-Vêt                  -     2229717.0  ...
# 12911        Enfant Nuit             FIABLE     2257563.0  ...
# 12912        Bébé Debout              LIEMO     2663928.0  ...
# 12917        Adulte Jour            TUTORAT     3231930.0  ...
#
#       cum_quantity_sold_POST num_sizes_POST num_stores_POST  \
# 1810                       1            0.0             0.0
# 1811                       0            0.0             0.0
# 1812                       0            0.0             0.0
# 1813                       0            0.0             0.0
# 1814                       0            0.0             0.0
# ...                      ...            ...             ...
# 12909                      3            1.0             3.0
# 12910                      1            1.0             1.0
# 12911                      1            1.0             1.0
# 12912                      0            2.0             2.0
# 12917                      2            2.0             3.0
#
#       first_week_sale_POST rate_of_sale_POST  cum_sellthrough_POST  \
# 1810              2018-S36                 -                    50
# 1811                     -                 -                     -
# 1812                     -                 -                     -
# 1813                     -                 -                     -
# 1814                     -                 -                     -
# ...                    ...               ...                   ...
# 12909             2018-S08              0.04                   100
# 12910             2018-S04              0.04                   100
# 12911             2018-S24              0.04                     7
# 12912             2018-S17              0.00                     0
# 12917             2018-S09              0.02                    67
#
#        warehouse_stock_POST zero_stock_POST  avail_warehouse_stock_POST  \
# 1810                      0             0.0                           0
# 1811                      0             0.0                           0
# 1812                      0             0.0                           0
# 1813                      0             0.0                           0
# 1814                      0             0.0                           0
# ...                     ...             ...                         ...
# 12909                     0             0.0                           0
# 12910                     0             0.0                           0
# 12911                   260             0.0                         260
# 12912                   529             0.0                         529
# 12917                     0             0.0                           0
#
#        %_POST
# 1810      0.0
# 1811      0.0
# 1812      0.0
# 1813      0.0
# 1814      0.0
# ...       ...
# 12909     0.0
# 12910     0.0
# 12911    20.0
# 12912    50.0
# 12917     0.0
#
# [2639 rows x 74 columns]

# %%
for col in df.columns:
    try:
        df[col] = df[col].astype(float)
    except ValueError:
        print (f'leaving this {col} column as string')
# Out:
# leaving this delivery_PRE column as string
# leaving this window_display_PRE column as string
# leaving this target_PRE column as string
# leaving this gender_PRE column as string
# leaving this product_category_PRE column as string
# leaving this family_PRE column as string
# leaving this sub_family_PRE column as string
# leaving this macro_category_PRE column as string
# leaving this reference_name_PRE column as string
# leaving this reference_PRE column as string
# leaving this description_PRE column as string
# leaving this color_PRE column as string
# leaving this material_PRE column as string
# leaving this seasonality_PRE column as string
# leaving this price_PRE column as string
# leaving this sub_target_PRE column as string
# leaving this discount_rate_PRE column as string
# leaving this discount_rate_sub1_PRE column as string
# leaving this store_stock_PRE column as string
# leaving this stock_transit_PRE column as string
# leaving this total_store_stock_PRE column as string
# leaving this weekly_cover_PRE column as string
# leaving this cum_discount_rate_PRE column as string
# leaving this cum_quantity_sold_PRE column as string
# leaving this first_week_sale_PRE column as string
# leaving this rate_of_sale_PRE column as string
# leaving this cum_sellthrough_PRE column as string
# leaving this warehouse_stock_PRE column as string
# leaving this avail_warehouse_stock_PRE column as string
# leaving this season_PRE column as string
# leaving this reference_POST column as string
# leaving this seasonality_POST column as string
# leaving this price_POST column as string
# leaving this quantity_sold_POST column as string
# leaving this quantity_sold_sub1_POST column as string
# leaving this quantity_sold_sub3_POST column as string
# leaving this discount_rate_POST column as string
# leaving this discount_rate_sub1_POST column as string
# leaving this store_stock_POST column as string
# leaving this total_store_stock_POST column as string
# leaving this weekly_cover_POST column as string
# leaving this cum_discount_rate_POST column as string
# leaving this cum_quantity_sold_POST column as string
# leaving this first_week_sale_POST column as string
# leaving this rate_of_sale_POST column as string
# leaving this cum_sellthrough_POST column as string
# leaving this warehouse_stock_POST column as string
# leaving this avail_warehouse_stock_POST column as string
# /var/folders/h5/gjdh07b54kxcq7yq7v2s0gbh0000gn/T/ipykernel_45557/4246995741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(float)
